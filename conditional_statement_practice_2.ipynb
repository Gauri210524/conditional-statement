# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauri210524/conditional-statement/blob/main/conditional_statement_practice_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
email=input("enter your email")
password=input("enter your password")
if email=="gauri1234@" and password=="12345":
  print("login successfull")
elif email=="gauri1234@" and password!="12345":
  # tell the user
  print("password is incorrect")
  password=input("enter your password again")
  if password=="12345":
    print("finally correct")
  else:
      print("still incorrect")
elif email!="gauri1234@" and password=="12345":
    # tell the user
    print("email is incorrect")
    email=input("enter your email again")
if email=="gauri1234@":
      print("finally correct")
else:
     print("still incorrect")
     print("login failed")
# Out:
# enter your emailgauri1234@
# enter your password56788
# password is incorrect
# enter your password again12345
# finally correct
# finally correct
