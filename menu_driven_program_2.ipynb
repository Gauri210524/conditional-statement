# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauri210524/conditional-statement/blob/main/menu_driven_program_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# menu driven program
# take the input from user
pin=input("""
hi! how can i help you
1.enter 1 for pin change
2.enter 2 for balance check
3.enter 3 for bithdrowl
4.enter 4 for exit
""")
if pin=="1":
    print("pin change")
elif pin=="2":
    print("balance check")
elif pin=="3":
    print("bithdrowl")
else:
     print("exit")
# Out:
# hi! how can i help you
# 1.enter 1 for pin change
# 2.enter 2 for balance check
# 3.enter 3 for bithdrowl
# 4.enter 4 for exit
# 4
# exit
