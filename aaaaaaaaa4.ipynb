# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauri210524/conditional-statement/blob/main/aaaaaaaaa4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s="python programming"
for i in s:
  if i =="p":
    pass
  elif i =="y":
    continue
  elif i =="g":
    break
  else:
    print(i, end=" ")
# Out:
# t h o n   r o
