# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauri210524/conditional-statement/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# find the largest number
# take the input from user
a=input("enter the first number:")
b=input("enter the second number:")
c=input("enter the third number:")
if a>b and a>c:
     print(a,"is greater")
elif b>c:
    print(b,"is greater")
else:
   print(c,"is greater")
# Out:
# enter the first number:5
# enter the second number:7
# enter the third number:2
# 7 is greater

# %%
# find the smallest number
# take the input from user
a=input("enter the first number:")
b=input("enter the second number:")
c=input("enter the third number:")
if a<b and a<c:
    print(a,"is the smallest number")
elif b<c:
    print(b,"is the smallest number")
else:
    print(c,"is the smallest number")
# Out:
# enter the first number:5
# enter the second number:1
# enter the third number:7
# 1 is the smallest number
